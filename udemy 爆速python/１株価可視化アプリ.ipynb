# %%
# !pip3 install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.59.tar.gz (25 kB)
# Requirement already satisfied: pandas>=0.24 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.1.3)
# Requirement already satisfied: numpy>=1.15 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (1.19.2)
# Requirement already satisfied: requests>=2.20 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (2.24.0)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.9.tar.gz (8.1 kB)
# Requirement already satisfied: lxml>=4.5.1 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from yfinance) (4.6.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20->yfinance) (1.25.11)
# Requirement already satisfied: six>=1.5 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: yfinance, multitasking
#   Building wheel for yfinance (setup.py) ... done
#   Created wheel for yfinance: filename=yfinance-0.1.59-py2.py3-none-any.whl size=23442 sha256=bfa01626fe73960ae78b6d5b498b7bb8daa2c9f320fa4442fc67bdb5692c876d
#   Stored in directory: /Users/uedaasagi/Library/Caches/pip/wheels/7e/d5/f4/f628965651f61ae35c2bdc73571ce1a2026e1550a336b5ad4b
#   Building wheel for multitasking (setup.py) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8367 sha256=8432f5fc14f9987842d7562d914fae132d2e58feb668283b346773324dfb69cd
#   Stored in directory: /Users/uedaasagi/Library/Caches/pip/wheels/57/6d/a3/a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# Installing collected packages: multitasking, yfinance
# Successfully installed multitasking-0.0.9 yfinance-0.1.59

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import yfinance as yf
# %matplotlib inline

# %%
aapl = yf.Ticker('AAPL')

# %%
days = 50
hist = aapl.history(period=f'{days}d') 
hist
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-03-11  122.332207  123.001069  121.054379  121.753189  103026500
# 2021-03-12  120.195839  120.964530  118.957944  120.824768   88105100
# 2021-03-15  121.204128  123.789732  120.215801  123.779747   92403800
# 2021-03-16  125.486848  127.004275  124.508514  125.357071  115227900
# 2021-03-17  123.839652  125.646580  122.132544  124.548447  111932600
# 2021-03-18  122.671628  122.971123  120.115972  120.325615  121229700
# 2021-03-19  119.696686  121.224090  119.477058  119.786530  185549500
# 2021-03-22  120.125962  123.659960  120.056081  123.180771  111912300
# 2021-03-23  123.120876  124.029329  121.932891  122.332214   95467100
# 2021-03-24  122.611734  122.691600  119.866397  119.886360   88530500
# 2021-03-25  119.337298  121.453706  118.798213  120.385513   98844700
# 2021-03-26  120.145921  121.274010  118.718345  121.004463   94071200
# 2021-03-29  121.443720  122.372143  120.525281  121.184158   80819200
# 2021-03-30  119.906329  120.195838  118.658448  119.696686   85671900
# 2021-03-31  121.443719  123.310543  120.944567  121.942871  118323800
# 2021-04-01  123.450312  123.969427  122.282290  122.791428   75089100
# 2021-04-05  123.659959  125.946077  122.861313  125.686516   88651200
# 2021-04-06  126.285496  126.914425  125.436939  125.995987   80171300
# 2021-04-07  125.616631  127.703083  124.927799  127.683121   83466700
# 2021-04-08  128.731334  130.168894  128.302070  130.138947   88844600
# 2021-04-09  129.579904  132.814401  129.250462  132.774475  106686700
# 2021-04-12  132.295284  132.624727  130.408490  131.017456   91420000
# 2021-04-13  132.215426  134.431663  131.706281  134.202042   91266500
# 2021-04-14  134.711191  134.771087  131.436754  131.806122   87222800
# 2021-04-15  133.593087  134.771079  133.413385  134.271927   89347100
# 2021-04-16  134.072272  134.441640  133.053998  133.932510   84922400
# 2021-04-19  133.283597  135.240280  133.113887  134.611343   94264200
# 2021-04-20  134.791058  135.300187  131.586494  132.884293   94812300
# 2021-04-21  132.135554  133.523197  131.077354  133.273621   68847100
# 2021-04-22  132.814404  133.922522  131.187178  131.716278   84566500
# 2021-04-23  131.935898  134.890871  131.935898  134.092239   78657500
# 2021-04-26  134.601376  134.830982  133.333525  134.491562   66905100
# 2021-04-27  134.781053  135.180384  133.882585  134.162109   66015800
# 2021-04-28  134.082243  134.791046  132.854333  133.353485  107760100
# 2021-04-29  136.238598  136.837586  132.225410  133.253662  151101000
# 2021-04-30  131.556541  133.333521  130.847753  131.237091  109713200
# 2021-05-03  131.816094  133.842666  131.606459  132.315247   75135100
# 2021-05-04  130.967542  131.267036  126.485150  127.633202  137564700
# 2021-05-05  128.980915  130.228796  127.753005  127.882790   84000900
# 2021-05-06  127.673135  129.529982  126.914422  129.520004   78128300
# 2021-05-07  130.850006  131.259995  129.479996  130.210007   78892700
# 2021-05-10  129.410004  129.539993  126.809998  126.849998   88071200
# 2021-05-11  123.500000  126.269997  122.769997  125.910004  126142800
# 2021-05-12  123.400002  124.639999  122.250000  122.769997  112172300
# 2021-05-13  124.580002  126.150002  124.260002  124.970001  105861300
# 2021-05-14  126.250000  127.889999  125.849998  127.449997   81806500
# 2021-05-17  126.820000  126.930000  125.169998  126.269997   74244600
# 2021-05-18  126.559998  126.989998  124.779999  124.849998   63342900
# 2021-05-19  123.160004  124.919998  122.860001  124.690002   92612000
# 2021-05-20  125.230003  127.720001  125.099998  127.309998   76756000
#
#             Dividends  Stock Splits
# Date
# 2021-03-11       0.00             0
# 2021-03-12       0.00             0
# 2021-03-15       0.00             0
# 2021-03-16       0.00             0
# 2021-03-17       0.00             0
# 2021-03-18       0.00             0
# 2021-03-19       0.00             0
# 2021-03-22       0.00             0
# 2021-03-23       0.00             0
# 2021-03-24       0.00             0
# 2021-03-25       0.00             0
# 2021-03-26       0.00             0
# 2021-03-29       0.00             0
# 2021-03-30       0.00             0
# 2021-03-31       0.00             0
# 2021-04-01       0.00             0
# 2021-04-05       0.00             0
# 2021-04-06       0.00             0
# 2021-04-07       0.00             0
# 2021-04-08       0.00             0
# 2021-04-09       0.00             0
# 2021-04-12       0.00             0
# 2021-04-13       0.00             0
# 2021-04-14       0.00             0
# 2021-04-15       0.00             0
# 2021-04-16       0.00             0
# 2021-04-19       0.00             0
# 2021-04-20       0.00             0
# 2021-04-21       0.00             0
# 2021-04-22       0.00             0
# 2021-04-23       0.00             0
# 2021-04-26       0.00             0
# 2021-04-27       0.00             0
# 2021-04-28       0.00             0
# 2021-04-29       0.00             0
# 2021-04-30       0.00             0
# 2021-05-03       0.00             0
# 2021-05-04       0.00             0
# 2021-05-05       0.00             0
# 2021-05-06       0.00             0
# 2021-05-07       0.22             0
# 2021-05-10       0.00             0
# 2021-05-11       0.00             0
# 2021-05-12       0.00             0
# 2021-05-13       0.00             0
# 2021-05-14       0.00             0
# 2021-05-17       0.00             0
# 2021-05-18       0.00             0
# 2021-05-19       0.00             0
# 2021-05-20       0.00             0

# %%
hist.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
hist.head(3)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-03-11  122.332207  123.001069  121.054379  121.753189  103026500
# 2021-03-12  120.195839  120.964530  118.957944  120.824768   88105100
# 2021-03-15  121.204128  123.789732  120.215801  123.779747   92403800
#
#             Dividends  Stock Splits
# Date
# 2021-03-11        0.0             0
# 2021-03-12        0.0             0
# 2021-03-15        0.0             0

# %%
hist.index
# Out:
# DatetimeIndex(['2021-03-11', '2021-03-12', '2021-03-15', '2021-03-16',
#                '2021-03-17', '2021-03-18', '2021-03-19', '2021-03-22',
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-29', '2021-03-30', '2021-03-31', '2021-04-01',
#                '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08',
#                '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14',
#                '2021-04-15', '2021-04-16', '2021-04-19', '2021-04-20',
#                '2021-04-21', '2021-04-22', '2021-04-23', '2021-04-26',
#                '2021-04-27', '2021-04-28', '2021-04-29', '2021-04-30',
#                '2021-05-03', '2021-05-04', '2021-05-05', '2021-05-06',
#                '2021-05-07', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14', '2021-05-17', '2021-05-18',
#                '2021-05-19', '2021-05-20'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
hist.index = hist.index.strftime('%d %B %Y')

# %%
hist = hist[['Close']]
hist.columns = ['apple']
hist.head()
# Out:
#                     apple
# Date
# 11 March 2021  121.753189
# 12 March 2021  120.824768
# 15 March 2021  123.779747
# 16 March 2021  125.357071
# 17 March 2021  124.548447

# %%
hist = hist.T
hist
# Out:
# Date   11 March 2021  12 March 2021  15 March 2021  16 March 2021  \
# apple     121.753189     120.824768     123.779747     125.357071
#
# Date   17 March 2021  18 March 2021  19 March 2021  22 March 2021  \
# apple     124.548447     120.325615      119.78653     123.180771
#
# Date   23 March 2021  24 March 2021  ...  07 May 2021  10 May 2021  \
# apple     122.332214      119.88636  ...   130.210007   126.849998
#
# Date   11 May 2021  12 May 2021  13 May 2021  14 May 2021  17 May 2021  \
# apple   125.910004   122.769997   124.970001   127.449997   126.269997
#
# Date   18 May 2021  19 May 2021  20 May 2021
# apple   124.849998   124.690002   127.309998
#
# [1 rows x 50 columns]

# %%
hist.index.name = 'Name'

# %%
hist
# Out:
# Date   11 March 2021  12 March 2021  15 March 2021  16 March 2021  \
# Name
# apple     121.753189     120.824768     123.779747     125.357071
#
# Date   17 March 2021  18 March 2021  19 March 2021  22 March 2021  \
# Name
# apple     124.548447     120.325615      119.78653     123.180771
#
# Date   23 March 2021  24 March 2021  ...  07 May 2021  10 May 2021  \
# Name                                 ...
# apple     122.332214      119.88636  ...   130.210007   126.849998
#
# Date   11 May 2021  12 May 2021  13 May 2021  14 May 2021  17 May 2021  \
# Name
# apple   125.910004   122.769997   124.970001   127.449997   126.269997
#
# Date   18 May 2021  19 May 2021  20 May 2021
# Name
# apple   124.849998   124.690002   127.309998
#
# [1 rows x 50 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import yfinance as yf
# %matplotlib inline


def get_data(days, tickers):
    df = pd.DataFrame()

    for company in tickers.keys():
    # company = 'facebook'
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d') 
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook':'FB',
    'google': 'GOOGL',
    'microsoft':'MSFT',
    'netflix':'NFLX',
    'amazon':'AMZN'
}
get_data(days,tickers)
# Out:
# Date       23 April 2021  26 April 2021  27 April 2021  28 April 2021  \
# Name
# apple         134.092239     134.491562     134.162109     133.353485
# facebook      301.130005     303.040009     303.570007     307.100006
# google       2299.929932    2309.929932    2290.979980    2359.040039
# microsoft     260.548370     260.947449     261.366486     253.973541
# netflix       505.549988     510.299988     505.549988     506.519989
# amazon       3340.879883    3409.000000    3417.429932    3458.500000
#
# Date       29 April 2021  30 April 2021  03 May 2021  04 May 2021  \
# Name
# apple         133.253662     131.237091   132.315247   127.633202
# facebook      329.510010     325.079987   322.579987   318.359985
# google       2392.760010    2353.500000  2343.080078  2306.830078
# microsoft     251.928268     251.599030   251.279770   247.219147
# netflix       509.000000     513.469971   509.109985   503.179993
# amazon       3471.310059    3467.419922  3386.489990  3311.870117
#
# Date       05 May 2021  06 May 2021  07 May 2021  10 May 2021  11 May 2021  \
# Name
# apple       127.882790   129.520004   130.210007   126.849998   125.910004
# facebook    315.019989   320.019989   319.079987   305.970001   306.529999
# google     2314.770020  2337.350098  2351.929932  2291.750000  2270.060059
# microsoft   245.902191   249.154678   251.878387   246.610550   245.662735
# netflix     496.079987   499.549988   503.839996   486.690002   495.079987
# amazon     3270.540039  3306.370117  3291.610107  3190.489990  3223.909912
#
# Date       12 May 2021  13 May 2021  14 May 2021  17 May 2021  18 May 2021  \
# Name
# apple       122.769997   124.970001   127.449997   126.269997   124.849998
# facebook    302.549988   305.260010   315.940002   315.459991   309.959991
# google     2200.250000  2229.040039  2278.379883  2288.919922  2262.469971
# microsoft   238.449402   242.470108   247.578308   244.615158   242.520004
# netflix     484.980011   486.660004   493.369995   488.940002   486.279999
# amazon     3151.939941  3161.469971  3222.899902  3270.389893  3232.280029
#
# Date       19 May 2021  20 May 2021
# Name
# apple       124.690002   127.309998
# facebook    313.589996   318.609985
# google     2271.500000  2306.949951
# microsoft   243.119995   246.479996
# netflix     487.700012   501.670013
# amazon     3231.800049  3247.679932

# %%
# !pip3 install altair
# Out:
# Requirement already satisfied: altair in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (4.1.0)
# Requirement already satisfied: jsonschema in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: entrypoints in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: numpy in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (1.19.2)
# Requirement already satisfied: pandas>=0.18 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (1.1.3)
# Requirement already satisfied: toolz in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jinja2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from altair) (2.11.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: setuptools in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (50.3.1.post20201107)
# Requirement already satisfied: attrs>=17.4.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18->altair) (2020.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)

# %%
 import altair as alt
companies = ['apple',  'facebook']
data = df.loc[companies]

data.sort_index()
#アルファベット順に並び替え

data = data.T.reset_index()

data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'アメリカの株価'}
)

ymin, ymax = 300, 400
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("アメリカの株価:Q", stack= None, scale = alt.Scale(domain=[ymin, ymax])),
        color = 'Name:N'
    )
)

# %%
chart
# Out:
# alt.Chart(...)
