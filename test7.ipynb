# %%
import  os

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'secret.json'

# %%
# !pip3 install --upgrade google-cloud-texttospeech
# Out:
# Collecting google-cloud-texttospeech
#   Downloading google_cloud_texttospeech-2.3.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 900 kB/s eta 0:00:01
# Collecting google-api-core[grpc]<2.0.0dev,>=1.22.2
#   Downloading google_api_core-1.28.0-py2.py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 1.1 MB/s eta 0:00:01
# Collecting proto-plus>=1.4.0
#   Downloading proto_plus-1.18.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: packaging>=14.3 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (20.4)
# Collecting google-auth<2.0dev,>=1.25.0
#   Downloading google_auth-1.30.0-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3.0.0dev,>=2.18.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (2.24.0)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.53.0-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 1.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: protobuf>=3.12.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (3.15.8)
# Requirement already satisfied, skipping upgrade: pytz in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (2020.1)
# Requirement already satisfied, skipping upgrade: six>=1.13.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (50.3.1.post20201107)
# Collecting grpcio<2.0dev,>=1.29.0; extra == "grpc"
#   Downloading grpcio-1.38.0-cp38-cp38-macosx_10_10_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 2.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from packaging>=14.3->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (2.4.7)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (4.2.1)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (1.25.11)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (2020.6.20)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /Users/uedaasagi/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]<2.0.0dev,>=1.22.2->google-cloud-texttospeech) (3.0.4)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, google-auth, googleapis-common-protos, grpcio, google-api-core, proto-plus, google-cloud-texttospeech
# Successfully installed google-api-core-1.28.0 google-auth-1.30.0 google-cloud-texttospeech-2.3.0 googleapis-common-protos-1.53.0 grpcio-1.38.0 proto-plus-1.18.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.7.2

# %%
from google.cloud import texttospeech

client = texttospeech.TextToSpeechClient()

synthesis_input = texttospeech.SynthesisInput(text="　こんにちは！返事せえええや！！！ぼけえええ")


voice = texttospeech.VoiceSelectionParams(
    language_code="ja-JP", ssml_gender=texttospeech.SsmlVoiceGender.MALE
)

audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
)


response = client.synthesize_speech(
    input=synthesis_input, voice=voice, audio_config=audio_config
)
# filename = "output.mp3"
# with open(filename, "wb") as out:
#     out.write(response.audio_content)
#     print(f'音声データは{filename}ファイルに書き出しました。')

# %%
from IPython.display import Audio
Audio(response.audio_content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.cloud import texttospeech
from IPython.display import Audio

# %%
from google.cloud import texttospeech
from IPython.display import Audio

def synthesize_speech(text, lang ='日本語',gender= 'default'):
    gender_type = {
        'default':texttospeech.SsmlVoiceGender.SSML_VOICE_GENDER_UNSPECIFIED,
        'male' : texttospeech.SsmlVoiceGender.MALE,
        'female':texttospeech.SsmlVoiceGender.FEMALE,
        'neautral':texttospeech.SsmlVoiceGender.NEUTRAL
    }

    lang_code = {
        '英語':'en-US',
        '日本語':'ja-JP'
    }


  
    client = texttospeech.TextToSpeechClient()

    synthesis_input = texttospeech.SynthesisInput(text=text)


    voice = texttospeech.VoiceSelectionParams(
        language_code=lang_code[lang], ssml_gender=gender_type[gender]
    )

    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.MP3
    )


    response = client.synthesize_speech(
        input=synthesis_input, voice=voice, audio_config=audio_config

    )
    return response

# %%
gender = 'default'
lang = '英語'
text ="　こんにちは！返事せえや！！！ぼけえあほがあ"
text2="I am a dog. If you don't think so ,you are foolish.Then , is this right english sentence?"
 

response = synthesize_speech(text2, lang, gender= 'male')
Audio(response.audio_content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
